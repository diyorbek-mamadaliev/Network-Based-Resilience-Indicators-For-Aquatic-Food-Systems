# %%
from src.data.load_synthetic import load_synthetic_ecosystem
from src.network.build_layers import build_ecological_layer
from src.metrics.connectivity import largest_component_size
from src.simulation.shocks import remove_species

species, edges = load_synthetic_ecosystem(
    "data/raw/synthetic_ecosystem_v1.json"
)

G = build_ecological_layer(species, edges)

baseline = largest_component_size(G)

G_shock = remove_species(G, ["SmallFish"])
after_shock = largest_component_size(G_shock)

print("Baseline:", baseline)
print("After shock:", after_shock)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 from src.metrics.connectivity import largest_component_size
#       4 from src.simulation.shocks import remove_species
# ----> 6 species, edges = load_synthetic_ecosystem(
#       7     "data/raw/synthetic_ecosystem_v1.json"
#       8 )
#      10 G = build_ecological_layer(species, edges)
#      12 baseline = largest_component_size(G)
#
# File ~/PycharmProjects/Network-Based-Resilience-Indicators-For-Aquatic-Food-Systems/src/data/load_synthetic.py:4, in load_synthetic_ecosystem(path)
#       3 def load_synthetic_ecosystem(path):
# ----> 4     with open(path, "r") as f:
#       5         data = json.load(f)
#       7     species = [n["id"] for n in data["nodes"]]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/synthetic_ecosystem_v1.json'
